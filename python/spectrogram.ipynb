# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt 

x = librosa.load('./test2.wav')[0]
y = librosa.stft(x, n_fft=128, hop_length=64, win_length=128)

# %%
magnitude = np.abs(y)
log_spectrogram = (librosa.amplitude_to_db(magnitude))

# %%
plt.figure(figsize=(10,4))
librosa.display.specshow(log_spectrogram, sr=16000, hop_length=128, y_axis='linear')
plt.xlabel("Time")
plt.ylabel("Frequency")
plt.colorbar()
plt.title("Spectrogram (dB)")
plt.show()

# %%
arr = []
for i in np.arange(log_spectrogram[0].size):
    if log_spectrogram[23][i] > -10:
        arr.append(i)

# %%
arr
# Out:
# [283,
#  284,
#  285,
#  286,
#  287,
#  288,
#  289,
#  290,
#  291,
#  292,
#  293,
#  294,
#  295,
#  296,
#  297,
#  298,
#  299,
#  300,
#  301,
#  302,
#  303,
#  304,
#  305,
#  306,
#  307,
#  308,
#  309,
#  310,
#  311,
#  312,
#  313,
#  314,
#  315,
#  316,
#  317,
#  318,
#  319,
#  320,
#  321,
#  322,
#  323,
#  324,
#  325,
#  326,
#  327,
#  328,
#  329,
#  330,
#  331,
#  332,
#  333,
#  334,
#  335,
#  336,
#  337,
#  338,
#  339,
#  340,
#  341,
#  342,
#  343,
#  344,
#  345,
#  346,
#  347,
#  348,
#  349,
#  350,
#  351,
#  352,
#  353,
#  354,
#  355,
#  356,
#  357,
#  358,
#  359,
#  360,
#  361,
#  362,
#  363,
#  364,
#  365,
#  366,
#  367,
#  368,
#  369,
#  370,
#  371,
#  372,
#  373,
#  374,
#  375,
#  376,
#  377,
#  378,
#  379,
#  380,
#  381,
#  382,
#  383,
#  384,
#  385,
#  386,
#  387,
#  388,
#  389,
#  390,
#  391,
#  392,
#  393,
#  394,
#  395,
#  396,
#  397,
#  398,
#  399,
#  400,
#  401,
#  402,
#  403,
#  404,
#  405,
#  406,
#  407,
# ...

# %%
for i in range(677):
    if arr[i+1] != arr[i] + 1 :
        print(arr[i])
        print(arr[i+1])
# Out:
# 623
# 1414
